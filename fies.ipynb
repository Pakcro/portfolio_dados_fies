# %%
#Usado para integrar todos os arquivos CSV que se tratam de Inscritos.
import pandas as pd
import os

#Arquivos CSV
arquivos_csv = [
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2019\inscritos_2019_sem1.CSV',
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2019\inscritos_2019_sem2.CSV',
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2020\inscritos_2020_sem1.CSV',
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2020\inscritos_2020_sem2.CSV',
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2021\inscritos_2021_sem1.CSV',
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2021\inscritos_2021_sem2.CSV'
]

#Dataframe
dataframes = []

try:
    #Loop para ler cada arquivo CSV e adicionar ao DataFrame
    for arquivo in arquivos_csv:
        df = pd.read_csv(arquivo, encoding='latin1', delimiter=';', low_memory=False)
        dataframes.append(df)

    #Mesclar todos os DataFrames em um único DataFrame
    df_combinado = pd.concat(dataframes, ignore_index=True)

    #Nome do arquivo de saída
    output_file = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\inscritos_geral.csv'

    #Salvar o DataFrame combinado em um novo arquivo CSV
    df_combinado.to_csv(output_file, index=False, encoding='utf-8-sig')

    print(f"Arquivos combinados com sucesso! O arquivo resultante foi salvo em: {output_file}")

except FileNotFoundError as e:
    print(f"Erro: Um ou mais arquivos não foram encontrados. Detalhes: {e}")
except Exception as e:
    print(f"Ocorreu um erro inesperado: {e}")

# %%
#Usado para integrar todos os arquivos CSV que se tratam de Ofertas pelas Universidades.
import pandas as pd
import os

#Arquivos CSV
arquivos_csv = [
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2019\oferta_universidades_2019_sem1.CSV',
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2019\oferta_universidades_2019_sem2.CSV',
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2020\oferta_universidades_2020_sem1.CSV',
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2020\oferta_universidades_2020_sem2.CSV',
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2021\oferta_universidades_2021_sem1.CSV',
    r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\2021\oferta_universidades_2021_sem2.CSV'
]

#DataFrames
dataframes = []

try:
    #Loop para ler cada arquivo CSV e adicionar ao DataFrame
    for arquivo in arquivos_csv:
        df = pd.read_csv(arquivo, encoding='latin1', delimiter=';', low_memory=False)
        dataframes.append(df)

    #Mesclar todos os DataFrames em um único DataFrame
    df_combinado = pd.concat(dataframes, ignore_index=True)

    #Nome do arquivo de saída
    output_file = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\oferta_universidades_geral.csv'

    #Salvar o DataFrame combinado em um novo arquivo CSV
    df_combinado.to_csv(output_file, index=False, encoding='utf-8-sig')

    print(f"Arquivos combinados com sucesso! O arquivo resultante foi salvo em: {output_file}")

except FileNotFoundError as e:
    print(f"Erro: Um ou mais arquivos não foram encontrados. Detalhes: {e}")
except Exception as e:
    print(f"Ocorreu um erro inesperado: {e}")

# %%
#Analise Exploratoria
import pandas as pd

#Arquivos CSV
insc = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\inscritos_geral.csv'
ofer = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\oferta_universidades_geral.csv'

#Leitura dos arquivos
df_insc = pd.read_csv(insc, encoding='utf-8', delimiter=',', low_memory=False)
df_ofer = pd.read_csv(ofer, encoding='utf-8', delimiter=',', low_memory=False)

#Funções para explorar o dataset
def explorar_dataset(df, nome_arquivo):
    print(f"\n=== Explorando o arquivo: {nome_arquivo} ===")
    
    #Primeiras linhas
    print("\nPrimeiras linhas do dataset:")
    print(df.head())
    
    #Informações gerais
    print("\nInformações gerais do dataset:")
    print(df.info())
    
    #Estatísticas descritivas (numéricas)
    print("\nEstatísticas descritivas (colunas numéricas):")
    print(df.describe())
    
    #Estatísticas descritivas (categóricas)
    print("\nEstatísticas descritivas (colunas categóricas):")
    print(df.describe(include='object'))
    
    #Valores nulos
    print("\nContagem de valores nulos por coluna:")
    print(df.isnull().sum())
    
    #Tamanho do dataset
    print("\nTamanho do dataset:")
    print(f"Linhas: {df.shape[0]}, Colunas: {df.shape[1]}")
    
    #Valores únicos por coluna
    print("\nValores únicos em cada coluna:")
    for coluna in df.columns:
        print(f"{coluna}: {df[coluna].nunique()} valores únicos")
    
    #Amostra aleatória de dados
    print("\nAmostra aleatória do dataset:")
    print(df.sample(5))

#Explorando os datasets
explorar_dataset(df_insc, "inscritos_geral.csv")
explorar_dataset(df_ofer, "oferta_universidades_geral.csv")
# Out:
# === Explorando o arquivo: inscritos_geral.csv ===
#
# Primeiras linhas do dataset:
#    Ano do processo seletivo  Semestre do processo seletivo  ID do estudante  \
# 0                      2019                              1         12780312
# 1                      2019                              1         90449596
# 2                      2019                              1         93618702
# 3                      2019                              1         99129205
# 4                      2019                              1         90525753
#
#   Sexo Data de Nascimento UF de residência Municipio de residência Etnia/Cor  \
# 0    F           14/04/00               PR                CURITIBA    BRANCA
# 1    F           13/04/76               PR                CURITIBA    BRANCA
# 2    F           17/11/01               PR                CURITIBA    BRANCA
# 3    F           13/09/99               PR                CURITIBA    BRANCA
# 4    F           18/11/98               PR                 COLOMBO     PRETA
#
#   Pessoa com deficiência? Tipo de escola no ensino médio  ...  \
# 0                     NÃO                            NÃO  ...
# 1                     NÃO                            NÃO  ...
# 2                     NÃO                            NÃO  ...
# 3                     NÃO                            NÃO  ...
# 4                     NÃO                            SIM  ...
#
#    Ciências Natureza e suas Tec Ciências Humanas e suas Tec  \
# 0                         648,5                       658,5
# 1                         420,3                       505,7
# 2                         590,3                       572,2
# 3                         597,1                       583,1
# 4                         568,1                       619,9
#
#   Situação Inscrição Fies  Percentual de financiamento  \
# 0    OPÇÃO NÃO CONTRATADA                          NaN
# 1          NÃO CONTRATADO                          NaN
# 2              CONTRATADA                           50
# 3    OPÇÃO NÃO CONTRATADA                          NaN
# 4          NÃO CONTRATADO                          NaN
#
#   Semestre do financiamento Qtde semestre financiado Classificação  \
# 0                       NaN                      8.0           NaN
# 1                                                NaN           NaN
# 2                        1º                      8.0           NaN
# 3                       NaN                      8.0           NaN
# 4                                                NaN           NaN
#
#   Cod. do Grupo de preferência2  Modalidade de Financiamento  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#   Situação Inscrição P-FIES
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 61 columns]
#
# Informações gerais do dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2217921 entries, 0 to 2217920
# Data columns (total 61 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Ano do processo seletivo        int64
#  1   Semestre do processo seletivo   int64
#  2   ID do estudante                 int64
#  3   Sexo                            object
#  4   Data de Nascimento              object
#  5   UF de residência                object
#  6   Municipio de residência         object
#  7   Etnia/Cor                       object
#  8   Pessoa com deficiência?         object
#  9   Tipo de escola no ensino médio  object
#  10  Ano conclusão ensino médio      int64
#  11  Concluiu curso superior?        object
#  12  Professor rede pública ensino?  object
#  13  Nº de membros Grupo Familiar    int64
#  14  Renda familiar mensal bruta     object
#  15  Renda mensal bruta per capita   object
#  16  Região grupo de preferência     object
#  17  UF                              object
#  18  Cod.Microrregião                int64
#  19  Microrregião                    object
#  20  Cod.Mesorregião                 int64
#  21  Mesorregião                     object
#  22  Conceito de curso do GP         object
#  23  Área do conhecimento            object
#  24  Subárea do conhecimento         object
#  25  Cod. do Grupo de preferência    int64
#  26  Nota Corte Grupo Preferência    object
#  27  Opções de cursos da inscrição   int64
#  28  Nome mantenedora                object
#  29  Natureza Jurídica Mantenedora   object
#  30  CNPJ da mantenedora             int64
#  31  Código e-MEC da Mantenedora     int64
#  32  Nome da IES                     object
#  33  Código e-MEC da IES             int64
#  34  Organização Acadêmica da IES    object
#  35  Município da IES                object
#  36  UF da IES                       object
#  37  Nome do Local de oferta         object
#  38  Código do Local de Oferta       int64
#  39  Munícipio do Local de Oferta    object
#  40  UF do Local de Oferta           object
#  41  Código do curso                 int64
#  42  Nome do curso                   object
#  43  Turno                           object
#  44  Grau                            object
#  45  Conceito                        object
#  46  Média nota Enem                 object
#  47  Ano do Enem                     float64
#  48  Redação                         object
#  49  Matemática e suas Tecnologias   object
#  50  Linguagens, Códigos e suas Tec  object
#  51  Ciências Natureza e suas Tec    object
#  52  Ciências Humanas e suas Tec     object
#  53  Situação Inscrição Fies         object
#  54  Percentual de financiamento     object
#  55  Semestre do financiamento       object
#  56  Qtde semestre financiado        float64
#  57  Classificação                   float64
#  58  Cod. do Grupo de preferência2   float64
#  59  Modalidade de Financiamento     object
#  60  Situação Inscrição P-FIES       object
# dtypes: float64(4), int64(14), object(43)
# memory usage: 1.0+ GB
# None
#
# Estatísticas descritivas (colunas numéricas):
#        Ano do processo seletivo  Semestre do processo seletivo  \
# count              2.217921e+06                   2.217921e+06
# mean               2.019786e+03                   1.325632e+00
# std                7.842054e-01                   4.686104e-01
# min                2.019000e+03                   1.000000e+00
# 25%                2.019000e+03                   1.000000e+00
# 50%                2.020000e+03                   1.000000e+00
# 75%                2.020000e+03                   2.000000e+00
# max                2.021000e+03                   2.000000e+00
#
#        ID do estudante  Ano conclusão ensino médio  \
# count     2.217921e+06                2.217921e+06
# mean      1.712072e+08                2.014551e+03
# std       8.712671e+07                5.292533e+00
# min       1.251817e+07                1.961000e+03
# 25%       9.753596e+07                2.013000e+03
# 50%       2.020230e+08                2.016000e+03
# 75%       2.039443e+08                2.018000e+03
# max       3.534557e+08                2.021000e+03
#
#        Nº de membros Grupo Familiar  Cod.Microrregião  Cod.Mesorregião  \
# count                  2.217921e+06      2.217921e+06     2.217921e+06
# mean                   1.921765e+00      3.037387e+04     3.040586e+03
# std                    1.292647e+00      1.001370e+04     1.001869e+03
# min                    0.000000e+00      1.100100e+04     1.101000e+03
# 25%                    1.000000e+00      2.303200e+04     2.307000e+03
# 50%                    2.000000e+00      3.103000e+04     3.107000e+03
# 75%                    3.000000e+00      3.506100e+04     3.515000e+03
# max                    2.900000e+01      5.300100e+04     5.301000e+03
#
#        Cod. do Grupo de preferência  Opções de cursos da inscrição  \
# count                  2.217921e+06                   2.217921e+06
# mean                   7.026355e+04                   1.689534e+00
# std                    3.052079e+04                   7.761125e-01
# min                    4.258300e+04                   1.000000e+00
# 25%                    4.611900e+04                   1.000000e+00
# 50%                    5.716000e+04                   1.000000e+00
# 75%                    9.142900e+04                   2.000000e+00
# max                    1.268090e+05                   3.000000e+00
#
#        CNPJ da mantenedora  Código e-MEC da Mantenedora  Código e-MEC da IES  \
# count         2.217921e+06                 2.217921e+06         2.217921e+06
# mean          2.058100e+13                 3.082828e+03         3.167767e+03
# std           2.327381e+13                 5.076316e+03         4.926557e+03
# min           5.985700e+10                 1.000000e+01         1.000000e+01
# 25%           3.945249e+12                 3.630000e+02         4.660000e+02
# 50%           7.714798e+12                 1.119000e+03         1.502000e+03
# 75%           3.407574e+13                 2.415000e+03         3.029000e+03
# max           9.803985e+13                 1.805500e+04         2.455000e+04
#
#        Código do Local de Oferta  Código do curso   Ano do Enem  \
# count               2.217921e+06     2.217921e+06  2.217919e+06
# mean                6.631807e+05     7.734225e+05  2.017543e+03
# std                 3.719329e+05     9.605055e+05  2.219257e+00
# min                 2.240000e+02     8.490000e+02  2.010000e+03
# 25%                 6.578480e+05     6.662700e+04  2.017000e+03
# 50%                 6.590960e+05     1.209180e+05  2.018000e+03
# 75%                 1.045224e+06     1.303403e+06  2.019000e+03
# max                 2.500004e+06     5.001566e+06  2.021000e+03
#
#        Qtde semestre financiado  Classificação  Cod. do Grupo de preferência2
# count             317779.000000  540353.000000                  540353.000000
# mean                   8.721017     197.457827                   58353.492008
# std                    1.966426     324.683990                    1362.935618
# min                    0.000000       1.000000                   56313.000000
# 25%                    8.000000      27.000000                   57134.000000
# 50%                   10.000000      81.000000                   58239.000000
# 75%                   10.000000     227.000000                   59595.000000
# max                   16.000000    3014.000000                   61041.000000
#
# Estatísticas descritivas (colunas categóricas):
#            Sexo Data de Nascimento UF de residência Municipio de residência  \
# count   2217921            2217921          2217903                 2217921
# unique        3              27980               27                    5246
# top           F           08/03/01               SP               SÃO PAULO
# freq    1454004                917           333161                   93356
#
#        Etnia/Cor Pessoa com deficiência? Tipo de escola no ensino médio  \
# count    2217921                 2217921                        2217921
# unique         5                       2                              3
# top        PARDA                     NÃO                            SIM
# freq     1074705                 2198768                        1680795
#
#        Concluiu curso superior? Professor rede pública ensino?  \
# count                   2217921                        2217921
# unique                        2                              2
# top                         NÃO                            NÃO
# freq                    2040747                        2082365
#
#        Renda familiar mensal bruta  ...  Redação  \
# count                      1947981  ...  2217920
# unique                      170418  ...      107
# top                            998  ...      560
# freq                         73616  ...   172631
#
#        Matemática e suas Tecnologias Linguagens, Códigos e suas Tec  \
# count                        2217920                        2217920
# unique                          6121                           4203
# top                            494,8                          532,1
# freq                            1112                           1861
#
#        Ciências Natureza e suas Tec Ciências Humanas e suas Tec  \
# count                       2217920                     2217920
# unique                         4583                        4798
# top                           483,9                       568,9
# freq                           1406                        1389
#
#        Situação Inscrição Fies Percentual de financiamento  \
# count                  2217921                      160404
# unique                       8                        4796
# top             NÃO CONTRATADO                          50
# freq                   1044549                       24373
#
#        Semestre do financiamento Modalidade de Financiamento  \
# count                    2060546                      540353
# unique                        13                           3
# top                                          Modalidade FIES
# freq                     1900142                      291660
#
#                   Situação Inscrição P-FIES
# count                                540353
# unique                                    2
# top     Não aprovada pelo Agente Financeiro
# freq                                 540139
#
# [4 rows x 43 columns]
#
# Contagem de valores nulos por coluna:
# Ano do processo seletivo               0
# Semestre do processo seletivo          0
# ID do estudante                        0
# Sexo                                   0
# Data de Nascimento                     0
#                                   ...
# Qtde semestre financiado         1900142
# Classificação                    1677568
# Cod. do Grupo de preferência2    1677568
# Modalidade de Financiamento      1677568
# Situação Inscrição P-FIES        1677568
# Length: 61, dtype: int64
#
# Tamanho do dataset:
# Linhas: 2217921, Colunas: 61
#
# Valores únicos em cada coluna:
# Ano do processo seletivo: 3 valores únicos
# Semestre do processo seletivo: 2 valores únicos
# ID do estudante: 1109893 valores únicos
# Sexo: 3 valores únicos
# Data de Nascimento: 27980 valores únicos
# UF de residência: 27 valores únicos
# Municipio de residência: 5246 valores únicos
# Etnia/Cor: 5 valores únicos
# Pessoa com deficiência?: 2 valores únicos
# Tipo de escola no ensino médio: 3 valores únicos
# Ano conclusão ensino médio: 57 valores únicos
# Concluiu curso superior?: 2 valores únicos
# Professor rede pública ensino?: 2 valores únicos
# Nº de membros Grupo Familiar: 23 valores únicos
# Renda familiar mensal bruta: 170418 valores únicos
# Renda mensal bruta per capita: 145331 valores únicos
# Região grupo de preferência: 5 valores únicos
# UF: 27 valores únicos
# Cod.Microrregião: 360 valores únicos
# Microrregião: 359 valores únicos
# Cod.Mesorregião: 130 valores únicos
# Mesorregião: 130 valores únicos
# Conceito de curso do GP: 4 valores únicos
# Área do conhecimento: 4 valores únicos
# Subárea do conhecimento: 34 valores únicos
# Cod. do Grupo de preferência: 24561 valores únicos
# Nota Corte Grupo Preferência: 9136 valores únicos
# Opções de cursos da inscrição: 3 valores únicos
# Nome mantenedora: 1165 valores únicos
# Natureza Jurídica Mantenedora: 9 valores únicos
# CNPJ da mantenedora: 1087 valores únicos
# Código e-MEC da Mantenedora: 1087 valores únicos
# Nome da IES: 2039 valores únicos
# Código e-MEC da IES: 1801 valores únicos
# Organização Acadêmica da IES: 3 valores únicos
# Município da IES: 601 valores únicos
# UF da IES: 27 valores únicos
# Nome do Local de oferta: 2012 valores únicos
# Código do Local de Oferta: 2871 valores únicos
# Munícipio do Local de Oferta: 653 valores únicos
# UF do Local de Oferta: 27 valores únicos
# Código do curso: 23576 valores únicos
# Nome do curso: 399 valores únicos
# Turno: 4 valores únicos
# Grau: 3 valores únicos
# Conceito: 4 valores únicos
# Média nota Enem: 16888 valores únicos
# Ano do Enem: 12 valores únicos
# Redação: 107 valores únicos
# Matemática e suas Tecnologias: 6121 valores únicos
# Linguagens, Códigos e suas Tec: 4203 valores únicos
# Ciências Natureza e suas Tec: 4583 valores únicos
# Ciências Humanas e suas Tec: 4798 valores únicos
# Situação Inscrição Fies: 8 valores únicos
# Percentual de financiamento: 4796 valores únicos
# Semestre do financiamento: 13 valores únicos
# Qtde semestre financiado: 16 valores únicos
# Classificação: 3014 valores únicos
# Cod. do Grupo de preferência2: 4546 valores únicos
# Modalidade de Financiamento: 3 valores únicos
# Situação Inscrição P-FIES: 2 valores únicos
#
# Amostra aleatória do dataset:
#          Ano do processo seletivo  Semestre do processo seletivo  \
# 1399834                      2020                              1
# 315615                       2019                              1
# 1438865                      2020                              1
# 1455903                      2020                              1
# 351461                       2019                              1
#
#          ID do estudante Sexo Data de Nascimento UF de residência  \
# 1399834        201871700    F         23/09/1997               SP
# 315615          12603215    M           24/02/95               MG
# 1438865        201928572    F         27/01/2000               PR
# 1455903        202396687    F         20/06/1998               RS
# 351461          90524968    F           17/04/00               MG
#
#         Municipio de residência Etnia/Cor Pessoa com deficiência?  \
# 1399834               SÃO PAULO    BRANCA                     NÃO
# 315615               UBERLÂNDIA    BRANCA                     NÃO
# 1438865        UNIÃO DA VITÓRIA    BRANCA                     NÃO
# 1455903            PORTO ALEGRE    BRANCA                     NÃO
# 351461                  GOUVEIA     PARDA                     NÃO
#
#         Tipo de escola no ensino médio  ...  Ciências Natureza e suas Tec  \
# 1399834                            SIM  ...                         434,4
# 315615                             SIM  ...                         418,6
# 1438865                        PARCIAL  ...                         480,2
# 1455903                            SIM  ...                         535,8
# 351461                             SIM  ...                         484,1
#
#         Ciências Humanas e suas Tec Situação Inscrição Fies  \
# 1399834                       641,6          NÃO CONTRATADO
# 315615                        557,3          NÃO CONTRATADO
# 1438865                       613,7         LISTA DE ESPERA
# 1455903                         438          NÃO CONTRATADO
# 351461                        551,3          NÃO CONTRATADO
#
#          Percentual de financiamento Semestre do financiamento  \
# 1399834                          NaN
# 315615                           NaN
# 1438865                          NaN
# 1455903                          NaN
# 351461                           NaN
#
#         Qtde semestre financiado Classificação Cod. do Grupo de preferência2  \
# 1399834                      NaN          66.0                       59667.0
# 315615                       NaN           NaN                           NaN
# 1438865                      NaN          18.0                       60045.0
# 1455903                      NaN         171.0                       60452.0
# 351461                       NaN           NaN                           NaN
#
#          Modalidade de Financiamento            Situação Inscrição P-FIES
# 1399834              Modalidade FIES  Não aprovada pelo Agente Financeiro
# 315615                           NaN                                  NaN
# 1438865              Modalidade FIES  Não aprovada pelo Agente Financeiro
# 1455903              Modalidade FIES  Não aprovada pelo Agente Financeiro
# 351461                           NaN                                  NaN
#
# [5 rows x 61 columns]
#
# === Explorando o arquivo: oferta_universidades_geral.csv ===
#
# Primeiras linhas do dataset:
#       Ano  Semestre                          Nome Mantenedora  \
# 0  2019.0       1.0  ANHANGUERA EDUCACIONAL PARTICIPACOES S/A
# 1  2019.0       1.0  CV & C CONSULTORES ASSOCIADOS LTDA - EPP
# 2  2019.0       1.0  ANHANGUERA EDUCACIONAL PARTICIPACOES S/A
# 3  2019.0       1.0   EDITORA E DISTRIBUIDORA EDUCACIONAL S/A
# 4  2019.0       1.0   EDITORA E DISTRIBUIDORA EDUCACIONAL S/A
#
#    Código e-MEC da Mantenedora  CNPJ da mantenedora  \
# 0                      16452.0         4.310392e+12
# 1                      12526.0         4.130323e+13
# 2                      16452.0         4.310392e+12
# 3                      14514.0         3.873365e+13
# 4                      14514.0         3.873365e+13
#
#                        Nome da IES  Código e-MEC da IES  \
# 0    Faculdade Anhanguera de Assis              21924.0
# 1   FACULDADE DE TECNOLOGIA ATENEU              13657.0
# 2    FACULDADE ANHANGÜERA DE BAURU               5451.0
# 3  FACULDADE PITÁGORAS DO MARANHÃO               1452.0
# 4  FACULDADE PITÁGORAS DO MARANHÃO               1452.0
#
#   Organização Acadêmica da IES UF da IES         Município da IES  ...  \
# 0                   Faculdade         SP                    Assis  ...
# 1                   Faculdade         CE  São Gonçalo do Amarante  ...
# 2                   Faculdade         SP                    Bauru  ...
# 3                   Faculdade         MA                 São Luís  ...
# 4                   Faculdade         MA                 São Luís  ...
#
#    11 Semestre FIES    12 Semestre FIES  Unnamed: 65 Unnamed: 66 Unnamed: 67  \
# 0               -                   -            NaN         NaN         NaN
# 1               -                   -            NaN         NaN         NaN
# 2               -                   -            NaN         NaN         NaN
# 3               -                   -            NaN         NaN         NaN
# 4               -                   -            NaN         NaN         NaN
#
#     Valor do curso para o FIES   Índice de correção - IPCA Unnamed: 58  \
# 0                           NaN                        NaN         NaN
# 1                           NaN                        NaN         NaN
# 2                           NaN                        NaN         NaN
# 3                           NaN                        NaN         NaN
# 4                           NaN                        NaN         NaN
#
#   Unnamed: 59 Unnamed: 60
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 73 columns]
#
# Informações gerais do dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168238 entries, 0 to 168237
# Data columns (total 73 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Ano                                143622 non-null  float64
#  1   Semestre                           143622 non-null  float64
#  2   Nome Mantenedora                   143622 non-null  object
#  3   Código e-MEC da Mantenedora        143622 non-null  float64
#  4   CNPJ da mantenedora                143622 non-null  float64
#  5   Nome da IES                        143622 non-null  object
#  6   Código e-MEC da IES                143622 non-null  float64
#  7   Organização Acadêmica da IES       143622 non-null  object
#  8   UF da IES                          143622 non-null  object
#  9   Município da IES                   143622 non-null  object
#  10  Nome do Local de oferta            143622 non-null  object
#  11  Código do Local de Oferta          143622 non-null  float64
#  12  Município do Local de Oferta       143622 non-null  object
#  13  UF do Local de Oferta              143622 non-null  object
#  14  Nome da Microrregião               143622 non-null  object
#  15  Código da Microrregião             143622 non-null  float64
#  16  Código da Mesorregião              143622 non-null  float64
#  17  Nome da Mesorregião                143622 non-null  object
#  18  Área do conhecimento               143622 non-null  object
#  19  Subárea do conhecimento            143622 non-null  object
#  20  Código do Grupo de Preferência     143622 non-null  float64
#  21   Nota de Corte Grupo Preferência   143622 non-null  object
#  22  Código do Curso                    143622 non-null  float64
#  23  Nome do Curso                      143622 non-null  object
#  24  Turno                              143622 non-null  object
#  25  Grau                               143622 non-null  object
#  26  Conceito                           143622 non-null  object
#  27  Vagas autorizadas e-mec            143622 non-null  float64
#  28  Vagas ofertadas FIES               143622 non-null  float64
#  29  Vagas além da Oferta               143622 non-null  float64
#  30  Vagas ocupadas                     143622 non-null  float64
#  31  Participa do P-FIES                74883 non-null   object
#  32  Vagas Ofertadas P-FIES             74883 non-null   float64
#  33  BANCO NORDESTE BRASIL   (004)      74883 non-null   object
#  34  ITAU UNIBANCO (PRAVALER)(341)      74883 non-null   object
#  35  BV FINANCEIRA (PRAVALER)(455)      74883 non-null   object
#  36  BANCO ANDBANK (PRAVALER)(65)       74883 non-null   object
#  37  BANCO DA AMAZONIA S.A.  (003)      74883 non-null   object
#  38   Valor bruto do curso              143622 non-null  object
#  39   1 Semestre Bruto                  143622 non-null  object
#  40   2 Semestre Bruto                  143622 non-null  object
#  41   3 Semestre Bruto                  143622 non-null  object
#  42   4 Semestre Bruto                  143622 non-null  object
#  43   5 Semestre Bruto                  143622 non-null  object
#  44   6 Semestre Bruto                  143622 non-null  object
#  45   7 Semestre Bruto                  143622 non-null  object
#  46   8 Semestre Bruto                  143622 non-null  object
#  47   9 Semestre Bruto                  143622 non-null  object
#  48   10 Semestre Bruto                 143622 non-null  object
#  49   11 Semestre Bruto                 143622 non-null  object
#  50   12 Semestre Bruto                 143622 non-null  object
#  51   Valor do curso para FIES          74883 non-null   object
#  52   Índice de correção - IPCA         74854 non-null   object
#  53   1 Semestre FIES                   143622 non-null  object
#  54   2 Semestre FIES                   143622 non-null  object
#  55   3 Semestre FIES                   143622 non-null  object
#  56   4 Semestre FIES                   143622 non-null  object
#  57   5 Semestre FIES                   143622 non-null  object
#  58   6 Semestre FIES                   143622 non-null  object
#  59   7 Semestre FIES                   143622 non-null  object
#  60   8 Semestre FIES                   143622 non-null  object
#  61   9 Semestre FIES                   143622 non-null  object
#  62   10 Semestre FIES                  143622 non-null  object
#  63   11 Semestre FIES                  143622 non-null  object
#  64   12 Semestre FIES                  143622 non-null  object
#  65  Unnamed: 65                        0 non-null       float64
#  66  Unnamed: 66                        0 non-null       float64
#  67  Unnamed: 67                        0 non-null       float64
#  68   Valor do curso para o FIES        68739 non-null   object
#  69  Índice de correção - IPCA          68739 non-null   object
#  70  Unnamed: 58                        0 non-null       float64
#  71  Unnamed: 59                        0 non-null       float64
#  72  Unnamed: 60                        0 non-null       float64
# dtypes: float64(21), object(52)
# memory usage: 93.7+ MB
# None
#
# Estatísticas descritivas (colunas numéricas):
#                  Ano       Semestre  Código e-MEC da Mantenedora  \
# count  143622.000000  143622.000000                143622.000000
# mean     2019.976097       1.468835                  4117.333598
# std         0.821468       0.499030                  6035.411385
# min      2019.000000       1.000000                    10.000000
# 25%      2019.000000       1.000000                   418.000000
# 50%      2020.000000       1.000000                  1179.000000
# 75%      2021.000000       2.000000                  2617.000000
# max      2021.000000       2.000000                 18055.000000
#
#        CNPJ da mantenedora  Código e-MEC da IES  Código do Local de Oferta  \
# count         1.436220e+05        143622.000000               1.436220e+05
# mean          2.258301e+13          3329.146489               6.681872e+05
# std           2.453032e+13          5080.608306               3.813419e+05
# min           5.985700e+10            10.000000               2.240000e+02
# 25%           4.310392e+12           466.000000               6.578390e+05
# 50%           9.099207e+12          1519.000000               6.592890e+05
# 75%           3.469935e+13          3304.000000               1.049596e+06
# max           9.803985e+13         24550.000000               2.500004e+06
#
#        Código da Microrregião  Código da Mesorregião  \
# count           143622.000000          143622.000000
# mean             32678.772967            3271.718588
# std               9340.675469             934.461208
# min              11001.000000            1101.000000
# 25%              28011.000000            2803.000000
# 50%              33018.000000            3306.000000
# 75%              35061.000000            3515.000000
# max              53001.000000            5301.000000
#
#        Código do Grupo de Preferência  Código do Curso  ...  \
# count                   143622.000000     1.436220e+05  ...
# mean                     80339.201425     7.919362e+05  ...
# std                      32596.159314     8.207751e+05  ...
# min                      42583.000000     8.490000e+02  ...
# 25%                      49164.000000     7.409600e+04  ...
# 50%                      60345.500000     1.111849e+06  ...
# 75%                     120239.000000     1.321981e+06  ...
# max                     126809.000000     5.001566e+06  ...
#
#        Vagas ofertadas FIES  Vagas além da Oferta  Vagas ocupadas  \
# count         143622.000000         143622.000000   143622.000000
# mean              30.803526             26.403441        1.177981
# std               27.581152             38.965285        3.272158
# min                1.000000              0.000000        0.000000
# 25%               15.000000              0.000000        0.000000
# 50%               25.000000             10.000000        0.000000
# 75%               40.000000             40.000000        1.000000
# max             1044.000000           1044.000000      218.000000
#
#        Vagas Ofertadas P-FIES  Unnamed: 65  Unnamed: 66  Unnamed: 67  \
# count            74883.000000          0.0          0.0          0.0
# mean                12.620114          NaN          NaN          NaN
# std                 23.496674          NaN          NaN          NaN
# min                  0.000000          NaN          NaN          NaN
# 25%                  0.000000          NaN          NaN          NaN
# 50%                  1.000000          NaN          NaN          NaN
# 75%                 15.000000          NaN          NaN          NaN
# max                700.000000          NaN          NaN          NaN
#
#        Unnamed: 58  Unnamed: 59  Unnamed: 60
# count          0.0          0.0          0.0
# mean           NaN          NaN          NaN
# std            NaN          NaN          NaN
# min            NaN          NaN          NaN
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max            NaN          NaN          NaN
#
# [8 rows x 21 columns]
#
# Estatísticas descritivas (colunas categóricas):
#                       Nome Mantenedora            Nome da IES  \
# count                           143622                 143622
# unique                            1175                   2085
# top     ASSUPERO ENSINO SUPERIOR LTDA.  UNIVERSIDADE PAULISTA
# freq                              7705                   6784
#
#        Organização Acadêmica da IES UF da IES Município da IES  \
# count                        143622    143622           143622
# unique                            3        27              619
# top                      Faculdade         SP        São Paulo
# freq                          64893     40338            21574
#
#        Nome do Local de oferta Município do Local de Oferta  \
# count                   143622                       143622
# unique                    2753                          669
# top               UNIDADE SEDE                    São Paulo
# freq                     15105                        16432
#
#        UF do Local de Oferta Nome da Microrregião         Nome da Mesorregião  \
# count                 143622               143622                      143622
# unique                    27                  362                         130
# top                       SP            São Paulo  Metropolitana de São Paulo
# freq                   39384                18229                       23609
#
#         ...  5 Semestre FIES   6 Semestre FIES   7 Semestre FIES   \
# count   ...            143622            143622            143622
# unique  ...             33500             33300             30817
# top     ...              -                 -                 -
# freq    ...             16242             21665             30172
#
#         8 Semestre FIES   9 Semestre FIES   10 Semestre FIES   \
# count             143622            143622             143622
# unique             31110             16789              17273
# top                 -                 -                  -
# freq               31757             81789              82807
#
#         11 Semestre FIES   12 Semestre FIES   Valor do curso para o FIES   \
# count              143622             143622                        68739
# unique                477                460                        29449
# top                  -                  -                      65.482,00
# freq               142729             142783                          157
#
#        Índice de correção - IPCA
# count                      68739
# unique                        95
# top                         100%
# freq                       15303
#
# [4 rows x 52 columns]
#
# Contagem de valores nulos por coluna:
# Ano                              24616
# Semestre                         24616
# Nome Mantenedora                 24616
# Código e-MEC da Mantenedora      24616
# CNPJ da mantenedora              24616
#                                  ...
#  Valor do curso para o FIES      99499
# Índice de correção - IPCA        99499
# Unnamed: 58                     168238
# Unnamed: 59                     168238
# Unnamed: 60                     168238
# Length: 73, dtype: int64
#
# Tamanho do dataset:
# Linhas: 168238, Colunas: 73
#
# Valores únicos em cada coluna:
# Ano: 3 valores únicos
# Semestre: 2 valores únicos
# Nome Mantenedora: 1175 valores únicos
# Código e-MEC da Mantenedora: 1096 valores únicos
# CNPJ da mantenedora: 1096 valores únicos
# Nome da IES: 2085 valores únicos
# Código e-MEC da IES: 1825 valores únicos
# Organização Acadêmica da IES: 3 valores únicos
# UF da IES: 27 valores únicos
# Município da IES: 619 valores únicos
# Nome do Local de oferta: 2753 valores únicos
# Código do Local de Oferta: 2910 valores únicos
# Município do Local de Oferta: 669 valores únicos
# UF do Local de Oferta: 27 valores únicos
# Nome da Microrregião: 362 valores únicos
# Código da Microrregião: 363 valores únicos
# Código da Mesorregião: 130 valores únicos
# Nome da Mesorregião: 130 valores únicos
# Área do conhecimento: 4 valores únicos
# Subárea do conhecimento: 34 valores únicos
# Código do Grupo de Preferência: 26903 valores únicos
#  Nota de Corte Grupo Preferência : 9137 valores únicos
# Código do Curso: 24549 valores únicos
# Nome do Curso: 420 valores únicos
# Turno: 4 valores únicos
# Grau: 4 valores únicos
# Conceito: 4 valores únicos
# Vagas autorizadas e-mec: 422 valores únicos
# Vagas ofertadas FIES: 312 valores únicos
# Vagas além da Oferta: 324 valores únicos
# Vagas ocupadas: 84 valores únicos
# Participa do P-FIES: 2 valores únicos
# Vagas Ofertadas P-FIES: 199 valores únicos
# BANCO NORDESTE BRASIL   (004): 2 valores únicos
# ITAU UNIBANCO (PRAVALER)(341): 2 valores únicos
# BV FINANCEIRA (PRAVALER)(455): 2 valores únicos
# BANCO ANDBANK (PRAVALER)(65): 2 valores únicos
# BANCO DA AMAZONIA S.A.  (003): 2 valores únicos
#  Valor bruto do curso : 54212 valores únicos
#  1 Semestre Bruto : 25244 valores únicos
#  2 Semestre Bruto : 29396 valores únicos
#  3 Semestre Bruto : 31164 valores únicos
#  4 Semestre Bruto : 31642 valores únicos
#  5 Semestre Bruto : 29360 valores únicos
#  6 Semestre Bruto : 29139 valores únicos
#  7 Semestre Bruto : 26990 valores únicos
#  8 Semestre Bruto : 27431 valores únicos
#  9 Semestre Bruto : 14947 valores únicos
#  10 Semestre Bruto : 15262 valores únicos
#  11 Semestre Bruto : 465 valores únicos
#  12 Semestre Bruto : 450 valores únicos
#  Valor do curso para FIES : 36755 valores únicos
#  Índice de correção - IPCA : 163 valores únicos
#  1 Semestre FIES : 29084 valores únicos
#  2 Semestre FIES : 33723 valores únicos
#  3 Semestre FIES : 35870 valores únicos
#  4 Semestre FIES : 36562 valores únicos
#  5 Semestre FIES : 33500 valores únicos
#  6 Semestre FIES : 33300 valores únicos
#  7 Semestre FIES : 30817 valores únicos
#  8 Semestre FIES : 31110 valores únicos
#  9 Semestre FIES : 16789 valores únicos
#  10 Semestre FIES : 17273 valores únicos
#  11 Semestre FIES : 477 valores únicos
#  12 Semestre FIES : 460 valores únicos
# Unnamed: 65: 0 valores únicos
# Unnamed: 66: 0 valores únicos
# Unnamed: 67: 0 valores únicos
#  Valor do curso para o FIES : 29449 valores únicos
# Índice de correção - IPCA: 95 valores únicos
# Unnamed: 58: 0 valores únicos
# Unnamed: 59: 0 valores únicos
# Unnamed: 60: 0 valores únicos
#
# Amostra aleatória do dataset:
#            Ano  Semestre                                   Nome Mantenedora  \
# 89396      NaN       NaN                                                NaN
# 7960    2019.0       1.0  UNIRON - UNIAO DAS ESCOLAS SUPERIORES DE RONDO...
# 147353  2021.0       2.0  CESMIG - CENTRO DE ENSINO SUPERIOR MINAS GERAI...
# 127458  2021.0       1.0            EDITORA E DISTRIBUIDORA EDUCACIONAL S/A
# 4127    2019.0       1.0           CENTRO DE ENSINO SUPERIOR PIAUIENSE LTDA
#
#         Código e-MEC da Mantenedora  CNPJ da mantenedora  \
# 89396                           NaN                  NaN
# 7960                         1144.0         3.327149e+12
# 147353                       1136.0         3.418437e+12
# 127458                      14514.0         3.873365e+13
# 4127                         1108.0         3.371400e+12
#
#                                  Nome da IES  Código e-MEC da IES  \
# 89396                                    NaN                  NaN
# 7960    FACULDADE DE EDUCAÇÃO DE PORTO VELHO               1515.0
# 147353                FACULDADE MINAS GERAIS               1720.0
# 127458     FACULDADE PITÁGORAS DE IMPERATRIZ               1847.0
# 4127            FACULDADE UNINASSAU TERESINA               1683.0
#
#        Organização Acadêmica da IES UF da IES Município da IES  ...  \
# 89396                           NaN       NaN              NaN  ...
# 7960                     Faculdade         RO      Porto Velho  ...
# 147353                   Faculdade         MG   Belo Horizonte  ...
# 127458                   Faculdade         MA       Imperatriz  ...
# 4127                     Faculdade         PI         Teresina  ...
#
#         11 Semestre FIES    12 Semestre FIES  Unnamed: 65 Unnamed: 66  \
# 89396                 NaN                 NaN         NaN         NaN
# 7960                 -                   -            NaN         NaN
# 147353               -                   -            NaN         NaN
# 127458               -                   -            NaN         NaN
# 4127                 -                   -            NaN         NaN
#
#        Unnamed: 67   Valor do curso para o FIES   Índice de correção - IPCA  \
# 89396          NaN                           NaN                        NaN
# 7960           NaN                           NaN                        NaN
# 147353         NaN                    77.940,00                       100%
# 127458         NaN                    55.610,18                        125%
# 4127           NaN                           NaN                        NaN
#
#        Unnamed: 58 Unnamed: 59 Unnamed: 60
# 89396          NaN         NaN         NaN
# 7960           NaN         NaN         NaN
# 147353         NaN         NaN         NaN
# 127458         NaN         NaN         NaN
# 4127           NaN         NaN         NaN
#
# [5 rows x 73 columns]

# %%
#Gráfico de evolução da procura pelos cursos
import pandas as pd
import matplotlib.pyplot as plt

#Arquivo CSV
insc = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\inscritos_geral.csv'

#Leitura do arquivo
df_insc = pd.read_csv(insc, encoding='utf-8', delimiter=',', low_memory=False)

#Contagem de cursos por ano
contagem_por_ano = df_insc.groupby(['Ano do processo seletivo', 'Nome do curso']).size().reset_index(name='Quantidade')

#Ordenando por ano e quantidade
contagem_por_ano = contagem_por_ano.sort_values(by=['Ano do processo seletivo', 'Quantidade'], ascending=[True, False])

#Filtrando os Top 3
top_cursos = contagem_por_ano.groupby('Nome do curso')['Quantidade'].sum().nlargest(3).index
dados_top_cursos = contagem_por_ano[contagem_por_ano['Nome do curso'].isin(top_cursos)]

#Criando o gráfico de linhas
plt.figure(figsize=(15, 8))

#Plotando os dados
for curso in top_cursos:
    curso_data = dados_top_cursos[dados_top_cursos['Nome do curso'] == curso]
    plt.plot(curso_data['Ano do processo seletivo'], curso_data['Quantidade'], marker='o', label=curso)

#Configurações do gráfico
plt.title('Top 3 Cursos Mais Procurados ao Longo dos Anos', fontsize=16)
plt.xlabel('Ano do Processo Seletivo', fontsize=12)
plt.ylabel('Quantidade de Inscrições', fontsize=12)
plt.xticks(dados_top_cursos['Ano do processo seletivo'].unique(), fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='Nome do Curso', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()

#Salvar o gráfico para Story Telling
plt.savefig('top3cursos.png', format='png', dpi=300)

#Exibindo o gráfico
plt.show()

# %%
#Gráfico de linhas para entendermos a evolução de inscritos por estado
import pandas as pd
import matplotlib.pyplot as plt

#Arquivo CSV
insc = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\inscritos_geral.csv'

#Leitura do arquivo
df_insc = pd.read_csv(insc, encoding='utf-8', delimiter=',', low_memory=False)

#Criando a contagem de UF por ano
contagem_por_ano = df_insc.groupby(['Ano do processo seletivo', 'UF']).size().reset_index(name='Quantidade')

#Ordenando por ano e quantidade
contagem_por_ano = contagem_por_ano.sort_values(by=['Ano do processo seletivo', 'Quantidade'], ascending=[True, False])

#Criando o gráfico de linhas
plt.figure(figsize=(15, 8))

#Para cada UF, cria uma linha no gráfico
for uf in contagem_por_ano['UF'].unique():
    uf_data = contagem_por_ano[contagem_por_ano['UF'] == uf]
    plt.plot(uf_data['Ano do processo seletivo'], uf_data['Quantidade'], marker='o', label=uf)

#Configurações do gráfico
plt.title('Quantidade de Inscrições por UF ao Longo dos Anos', fontsize=16)
plt.xlabel('Ano do Processo Seletivo', fontsize=12)
plt.ylabel('Quantidade de Inscrições', fontsize=12)
plt.xticks(contagem_por_ano['Ano do processo seletivo'].unique(), fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='UF', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()

#Salvar o gráfico para Story Telling
plt.savefig('top3cursos.png', format='png', dpi=300)

#Exibindo o gráfico
plt.show()

# %%
#Gráfico de linhas por estado que mais oferta vagas
import pandas as pd
import matplotlib.pyplot as plt

#Arquivo CSV
ofer = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\oferta_universidades_geral.csv'

#Leitura do arquivo
df_ofer = pd.read_csv(ofer, encoding='utf-8', delimiter=',', low_memory=False)

#Criando a contagem de UF por ano
contagem_por_ano = df_ofer.groupby(['Ano', 'UF do Local de Oferta']).size().reset_index(name='Quantidade')

#Somando as vagas totais por UF
vagas_por_uf = contagem_por_ano.groupby('UF do Local de Oferta')['Quantidade'].sum().reset_index()

#Selecionando as Top 5
top_5_ufs = vagas_por_uf.nlargest(5, 'Quantidade')['UF do Local de Oferta']

#Filtrando os dados apenas para as Top 5 UFs
dados_top_5 = contagem_por_ano[contagem_por_ano['UF do Local de Oferta'].isin(top_5_ufs)]

#Criando o gráfico de linhas
plt.figure(figsize=(15, 8))

#Para cada UF do Top 5, cria uma linha no gráfico
for uf in top_5_ufs:
    uf_data = dados_top_5[dados_top_5['UF do Local de Oferta'] == uf]
    plt.plot(uf_data['Ano'], uf_data['Quantidade'], marker='o', label=uf)

#Configurações do gráfico
plt.title('Top 5 UFs com Mais Vagas Ofertadas ao Longo dos Anos', fontsize=16)
plt.xlabel('Ano do Processo Seletivo', fontsize=12)
plt.ylabel('Quantidade de Vagas', fontsize=12)
plt.xticks(dados_top_5['Ano'].unique(), fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='UF', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()

#Salvar o gráfico para Story Telling
plt.savefig('top5_vagas_estados.png', format='png', dpi=300)

#Exibindo o gráfico
plt.show()

# %%
#Gráfico de oferta dos cursos por parte das universidade
import pandas as pd
import matplotlib.pyplot as plt

#Arquivo CSV
ofer = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\oferta_universidades_geral.csv'

#Leitura do arquivo
df_ofer = pd.read_csv(ofer, encoding='utf-8', delimiter=',', low_memory=False)

#Criando a contagem de cursos por ano
contagem_por_ano = df_ofer.groupby(['Ano', 'Nome do Curso']).size().reset_index(name='Quantidade')

#Ordenando por ano e quantidade
contagem_por_ano = contagem_por_ano.sort_values(by=['Ano', 'Quantidade'], ascending=[True, False])

#Filtrando os Top 3
top_cursos = contagem_por_ano.groupby('Nome do Curso')['Quantidade'].sum().nlargest(3).index
dados_top_cursos = contagem_por_ano[contagem_por_ano['Nome do Curso'].isin(top_cursos)]

#Criando o gráfico de linhas
plt.figure(figsize=(15, 8))

#Plotando os dados
for curso in top_cursos:
    curso_data = dados_top_cursos[dados_top_cursos['Nome do Curso'] == curso]
    plt.plot(curso_data['Ano'], curso_data['Quantidade'], marker='o', label=curso)

#Configurações do gráfico
plt.title('Top 3 Cursos Mais Ofertados ao Longo dos Anos', fontsize=16)
plt.xlabel('Ano do Processo Seletivo', fontsize=12)
plt.ylabel('Quantidade de Ofertas', fontsize=12)
plt.xticks(dados_top_cursos['Ano'].unique(), fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title='Nome do Curso', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()

#Salvar o gráfico para Story Telling
plt.savefig('top3ofertas.png', format='png', dpi=300)

#Exibindo o gráfico
plt.show()

# %%
#Cursos mais disputados relação quantidade de candidatos para quantidade de vagas
import pandas as pd
import matplotlib.pyplot as plt

#Arquivos CSV
insc = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\inscritos_geral.csv'
ofer = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\oferta_universidades_geral.csv'

#Leitura dos arquivos
df_insc = pd.read_csv(insc, encoding='utf-8', delimiter=',', low_memory=False)
df_ofer = pd.read_csv(ofer, encoding='utf-8', delimiter=',', low_memory=False)

#Renomear colunas para uniformidade
df_insc.rename(columns={'Ano do processo seletivo': 'Ano', 'Nome do curso': 'Curso'}, inplace=True)
df_ofer.rename(columns={'Ano': 'Ano', 'Nome do Curso': 'Curso'}, inplace=True)

#Criar contagem de inscritos e vagas por curso/ano
inscritos_por_curso = df_insc.groupby(['Ano', 'Curso']).size().reset_index(name='Inscritos')
vagas_por_curso = df_ofer.groupby(['Ano', 'Curso']).size().reset_index(name='Vagas')

#Mesclar os dados
dados_merged = pd.merge(inscritos_por_curso, vagas_por_curso, on=['Ano', 'Curso'], how='inner')

#Calcular a razão inscritos/vaga
dados_merged['Razão Inscritos/Vaga'] = (dados_merged['Inscritos'] / dados_merged['Vagas']).round(0)

#Criar gráficos por ano
anos = [2019, 2020, 2021]
for ano in anos:
    #Filtrar dados por ano
    dados_ano = dados_merged[dados_merged['Ano'] == ano].sort_values(by='Razão Inscritos/Vaga', ascending=False)
    
    #Selecionar os Top 5 cursos mais disputados para o ano
    top_cursos_disputados = dados_ano.head(5)
    
    #Criar o gráfico de barras
    plt.figure(figsize=(12, 6))
    plt.bar(top_cursos_disputados['Curso'], top_cursos_disputados['Razão Inscritos/Vaga'], color='blue')
    
    #Configurações do gráfico
    plt.title(f'Top 5 Cursos Mais Disputados em {ano} (Inscritos por Vaga)', fontsize=16)
    plt.xlabel('Curso', fontsize=12)
    plt.ylabel('Inscritos por Vaga', fontsize=12)
    plt.xticks(rotation=45, ha='right', fontsize=10)
    plt.tight_layout()
    
    #Salvar o gráfico
    plt.savefig(f'cursos_mais_disputados_{ano}.png', format='png', dpi=300)
    
    #Exibir o gráfico
    plt.show()

# %%
#Gráfico quanto a distribuição de inscritos por etnia
import pandas as pd
import matplotlib.pyplot as plt

#Arquivo CSV
ofer = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\inscritos_geral.csv'

#Leitura do arquivo
df_ofer = pd.read_csv(ofer, encoding='utf-8', delimiter=',', low_memory=False)

#Criando a contagem de cada etnia
contagem_etnia = df_ofer['Etnia/Cor'].value_counts()

#Calculando as porcentagens
porcentagem_etnia = (contagem_etnia / contagem_etnia.sum()) * 100

#Criando o gráfico de barras
plt.figure(figsize=(12, 6))
porcentagem_etnia.plot(kind='bar', color='blue')

#Configurações do gráfico
plt.title('Porcentagem de Cada Etnia/Cor', fontsize=16)
plt.xlabel('Etnia', fontsize=12)
plt.ylabel('Porcentagem (%)', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

#Salvando o gráfico
plt.savefig('porcentagem_etnia.png', format='png', dpi=300)

#Exibindo o gráfico
plt.show()

# %%
#Gráfico quanto a distribuição de sexo por etnia
import pandas as pd
import matplotlib.pyplot as plt

#Arquivo CSV
ofer = r'C:\Users\mathe\OneDrive\Documents\portfólio\fies\inscritos_geral.csv'

#Leitura do arquivo
df_ofer = pd.read_csv(ofer, encoding='utf-8', delimiter=',', low_memory=False)

#Criando a contagem de cada sexo
contagem_etnia = df_ofer['Sexo'].value_counts()

#Calculando as porcentagens
porcentagem_etnia = (contagem_etnia / contagem_etnia.sum()) * 100

#Criando o gráfico de barras
plt.figure(figsize=(12, 6))
porcentagem_etnia.plot(kind='bar', color='blue')

#Configurações do gráfico
plt.title('Porcentagem de Cada Sexo', fontsize=16)
plt.xlabel('Etnia', fontsize=12)
plt.ylabel('Porcentagem (%)', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

#Salvando o gráfico
plt.savefig('porcentagem_sexo.png', format='png', dpi=300)

#Exibindo o gráfico
plt.show()
